# %%
import csv
import os
from datetime import datetime

def convert_csv(input_file, output_file='output.csv'):
    # Extract symbol from the input filename
    symbol = os.path.splitext(os.path.basename(input_file))[0]
    
    with open(input_file, 'r', newline='', encoding='utf-8') as infile, \
         open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        
        reader = csv.reader(infile)
        writer = csv.writer(outfile)
        
        # Write the header to the output CSV
        header = ['symbol', 'Date', 'Open', 'High', 'Low', 'Close/Last', 'Volume']
        writer.writerow(header)
        
        # Skip the header row in the input CSV
        next(reader, None)
        
        for row in reader:
            if not row:
                continue  # Skip empty rows
            
            # Unpack the input row
            date_str, close_last, volume, open_price, high, low = row
            
            # Convert date from mm/dd/yyyy to yyyymmdd
            try:
                date_obj = datetime.strptime(date_str, '%m/%d/%Y')
                formatted_date = date_obj.strftime('%Y%m%d')
            except ValueError:
                print(f"Invalid date format: {date_str}")
                continue  # Skip rows with invalid dates
            
            # Remove '$' from numeric fields and convert to appropriate types
            close_last = close_last.replace('$', '').replace(',', '')
            open_price = open_price.replace('$', '').replace(',', '')
            high = high.replace('$', '').replace(',', '')
            low = low.replace('$', '').replace(',', '')
            volume = volume.replace('$', '').replace(',', '')
            
            # Create the output row
            output_row = [
                symbol,
                formatted_date,
                open_price,
                high,
                low,
                close_last,
                volume
            ]
            
            writer.writerow(output_row)

    print(f"Conversion complete. Output saved to '{output_file}'.")

# Example usage
if __name__ == "__main__":
    input_csv = 'NVDA.csv'  # Replace with your input CSV filename
    convert_csv(input_csv, 'NVDA_output.csv')  # Specify desired output filename
# Out:
# Invalid date format: 10-11-2024
# Invalid date format: 10-10-2024
# Invalid date format: 10-09-2024
# Invalid date format: 10-08-2024
# Invalid date format: 10-07-2024
# Invalid date format: 10-04-2024
# Invalid date format: 10-03-2024
# Invalid date format: 10-02-2024
# Invalid date format: 10-01-2024
# Invalid date format: 09-12-2024
# Invalid date format: 09-11-2024
# Invalid date format: 09-10-2024
# Invalid date format: 09-09-2024
# Invalid date format: 09-06-2024
# Invalid date format: 09-05-2024
# Invalid date format: 09-04-2024
# Invalid date format: 09-03-2024
# Invalid date format: 08-12-2024
# Invalid date format: 08-09-2024
# Invalid date format: 08-08-2024
# Invalid date format: 08-07-2024
# Invalid date format: 08-06-2024
# Invalid date format: 08-05-2024
# Invalid date format: 08-02-2024
# Invalid date format: 08-01-2024
# Invalid date format: 07-12-2024
# Invalid date format: 07-11-2024
# Invalid date format: 07-10-2024
# Invalid date format: 07-09-2024
# Invalid date format: 07-08-2024
# Invalid date format: 07-05-2024
# Invalid date format: 07-03-2024
# Invalid date format: 07-02-2024
# Invalid date format: 07-01-2024
# Invalid date format: 06-12-2024
# Invalid date format: 06-11-2024
# Invalid date format: 06-10-2024
# Invalid date format: 06-07-2024
# Invalid date format: 06-06-2024
# Invalid date format: 06-05-2024
# Invalid date format: 06-04-2024
# Invalid date format: 06-03-2024
# Invalid date format: 05-10-2024
# Invalid date format: 05-09-2024
# Invalid date format: 05-08-2024
# Invalid date format: 05-07-2024
# Invalid date format: 05-06-2024
# Invalid date format: 05-03-2024
# Invalid date format: 05-02-2024
# Invalid date format: 05-01-2024
# Invalid date format: 04-12-2024
# Invalid date format: 04-11-2024
# Invalid date format: 04-10-2024
# Invalid date format: 04-09-2024
# Invalid date format: 04-08-2024
# Invalid date format: 04-05-2024
# Invalid date format: 04-04-2024
# Invalid date format: 04-03-2024
# Invalid date format: 04-02-2024
# Invalid date format: 04-01-2024
# Invalid date format: 03-12-2024
# Invalid date format: 03-11-2024
# Invalid date format: 03-08-2024
# Invalid date format: 03-07-2024
# Invalid date format: 03-06-2024
# Invalid date format: 03-05-2024
# Invalid date format: 03-04-2024
# Invalid date format: 03-01-2024
# Invalid date format: 02-12-2024
# Invalid date format: 02-09-2024
# Invalid date format: 02-08-2024
# Invalid date format: 02-07-2024
# Invalid date format: 02-06-2024
# Invalid date format: 02-05-2024
# Invalid date format: 02-02-2024
# Invalid date format: 02-01-2024
# Invalid date format: 01-12-2024
# Invalid date format: 01-11-2024
# Invalid date format: 01-10-2024
# Invalid date format: 01-09-2024
# Invalid date format: 01-08-2024
# Invalid date format: 01-05-2024
# Invalid date format: 01-04-2024
# Invalid date format: 01-03-2024
# Invalid date format: 01-02-2024
# Invalid date format: 12-12-2023
# Invalid date format: 12-11-2023
# Invalid date format: 12-08-2023
# Invalid date format: 12-07-2023
# Invalid date format: 12-06-2023
# Invalid date format: 12-05-2023
# Invalid date format: 12-04-2023
# Invalid date format: 12-01-2023
# Invalid date format: 11-10-2023
# Invalid date format: 11-09-2023
# Invalid date format: 11-08-2023
# Invalid date format: 11-07-2023
# Invalid date format: 11-06-2023
# Invalid date format: 11-03-2023
# Invalid date format: 11-02-2023
# Invalid date format: 11-01-2023
# Invalid date format: 10-12-2023
# Invalid date format: 10-11-2023
# Invalid date format: 10-10-2023
# Invalid date format: 10-09-2023
# Invalid date format: 10-06-2023
# Invalid date format: 10-05-2023
# Invalid date format: 10-04-2023
# Invalid date format: 10-03-2023
# Invalid date format: 10-02-2023
# Invalid date format: 09-12-2023
# Invalid date format: 09-11-2023
# Invalid date format: 09-08-2023
# Invalid date format: 09-07-2023
# Invalid date format: 09-06-2023
# Invalid date format: 09-05-2023
# Invalid date format: 09-01-2023
# Invalid date format: 08-11-2023
# Invalid date format: 08-10-2023
# Invalid date format: 08-09-2023
# Invalid date format: 08-08-2023
# Invalid date format: 08-07-2023
# Invalid date format: 08-04-2023
# Invalid date format: 08-03-2023
# Invalid date format: 08-02-2023
# Invalid date format: 08-01-2023
# Invalid date format: 07-12-2023
# Invalid date format: 07-11-2023
# Invalid date format: 07-10-2023
# Invalid date format: 07-07-2023
# Invalid date format: 07-06-2023
# Invalid date format: 07-05-2023
# Invalid date format: 07-03-2023
# Invalid date format: 06-12-2023
# Invalid date format: 06-09-2023
# Invalid date format: 06-08-2023
# Invalid date format: 06-07-2023
# Invalid date format: 06-06-2023
# Invalid date format: 06-05-2023
# Invalid date format: 06-02-2023
# Invalid date format: 06-01-2023
# Invalid date format: 05-12-2023
# Invalid date format: 05-11-2023
# Invalid date format: 05-10-2023
# Invalid date format: 05-09-2023
# Invalid date format: 05-08-2023
# Invalid date format: 05-05-2023
# Invalid date format: 05-04-2023
# Invalid date format: 05-03-2023
# Invalid date format: 05-02-2023
# Invalid date format: 05-01-2023
# Invalid date format: 04-12-2023
# Invalid date format: 04-11-2023
# Invalid date format: 04-10-2023
# Invalid date format: 04-06-2023
# Invalid date format: 04-05-2023
# Invalid date format: 04-04-2023
# Invalid date format: 04-03-2023
# Invalid date format: 03-10-2023
# Invalid date format: 03-09-2023
# Invalid date format: 03-08-2023
# Invalid date format: 03-07-2023
# Invalid date format: 03-06-2023
# Invalid date format: 03-03-2023
# Invalid date format: 03-02-2023
# Invalid date format: 03-01-2023
# Invalid date format: 02-10-2023
# Invalid date format: 02-09-2023
# Invalid date format: 02-08-2023
# Invalid date format: 02-07-2023
# Invalid date format: 02-06-2023
# Invalid date format: 02-03-2023
# Invalid date format: 02-02-2023
# Invalid date format: 02-01-2023
# Invalid date format: 01-12-2023
# Invalid date format: 01-11-2023
# Invalid date format: 01-10-2023
# Invalid date format: 01-09-2023
# Invalid date format: 01-06-2023
# Invalid date format: 01-05-2023
# Invalid date format: 01-04-2023
# Invalid date format: 01-03-2023
# Invalid date format: 12-12-2022
# Invalid date format: 12-09-2022
# Invalid date format: 12-08-2022
# Invalid date format: 12-07-2022
# Invalid date format: 12-06-2022
# Invalid date format: 12-05-2022
# Invalid date format: 12-02-2022
# Invalid date format: 12-01-2022
# Invalid date format: 11-11-2022
# Invalid date format: 11-10-2022
# Invalid date format: 11-09-2022
# Invalid date format: 11-08-2022
# Invalid date format: 11-07-2022
# Invalid date format: 11-04-2022
# Invalid date format: 11-03-2022
# Invalid date format: 11-02-2022
# Invalid date format: 11-01-2022
# Invalid date format: 10-12-2022
# Invalid date format: 10-11-2022
# Invalid date format: 10-10-2022
# Invalid date format: 10-07-2022
# Invalid date format: 10-06-2022
# Invalid date format: 10-05-2022
# Invalid date format: 10-04-2022
# Invalid date format: 10-03-2022
# Invalid date format: 09-12-2022
# Invalid date format: 09-09-2022
# Invalid date format: 09-08-2022
# Invalid date format: 09-07-2022
# Invalid date format: 09-06-2022
# Invalid date format: 09-02-2022
# Invalid date format: 09-01-2022
# Invalid date format: 08-12-2022
# Invalid date format: 08-11-2022
# Invalid date format: 08-10-2022
# Invalid date format: 08-09-2022
# Invalid date format: 08-08-2022
# Invalid date format: 08-05-2022
# Invalid date format: 08-04-2022
# Invalid date format: 08-03-2022
# Invalid date format: 08-02-2022
# Invalid date format: 08-01-2022
# Invalid date format: 07-12-2022
# Invalid date format: 07-11-2022
# Invalid date format: 07-08-2022
# Invalid date format: 07-07-2022
# Invalid date format: 07-06-2022
# Invalid date format: 07-05-2022
# Invalid date format: 07-01-2022
# Invalid date format: 06-10-2022
# Invalid date format: 06-09-2022
# Invalid date format: 06-08-2022
# Invalid date format: 06-07-2022
# Invalid date format: 06-06-2022
# Invalid date format: 06-03-2022
# Invalid date format: 06-02-2022
# Invalid date format: 06-01-2022
# Invalid date format: 05-12-2022
# Invalid date format: 05-11-2022
# Invalid date format: 05-10-2022
# Invalid date format: 05-09-2022
# Invalid date format: 05-06-2022
# Invalid date format: 05-05-2022
# Invalid date format: 05-04-2022
# Invalid date format: 05-03-2022
# Invalid date format: 05-02-2022
# Invalid date format: 04-12-2022
# Invalid date format: 04-11-2022
# Invalid date format: 04-08-2022
# Invalid date format: 04-07-2022
# Invalid date format: 04-06-2022
# Invalid date format: 04-05-2022
# Invalid date format: 04-04-2022
# Invalid date format: 04-01-2022
# Invalid date format: 03-11-2022
# Invalid date format: 03-10-2022
# Invalid date format: 03-09-2022
# Invalid date format: 03-08-2022
# Invalid date format: 03-07-2022
# Invalid date format: 03-04-2022
# Invalid date format: 03-03-2022
# Invalid date format: 03-02-2022
# Invalid date format: 03-01-2022
# Invalid date format: 02-11-2022
# Invalid date format: 02-10-2022
# Invalid date format: 02-09-2022
# Invalid date format: 02-08-2022
# Invalid date format: 02-07-2022
# Invalid date format: 02-04-2022
# Invalid date format: 02-03-2022
# Invalid date format: 02-02-2022
# Invalid date format: 02-01-2022
# Invalid date format: 01-12-2022
# Invalid date format: 01-11-2022
# Invalid date format: 01-10-2022
# Invalid date format: 01-07-2022
# Invalid date format: 01-06-2022
# Invalid date format: 01-05-2022
# Invalid date format: 01-04-2022
# Invalid date format: 01-03-2022
# Invalid date format: 12-10-2021
# Invalid date format: 12-09-2021
# Invalid date format: 12-08-2021
# Invalid date format: 12-07-2021
# Invalid date format: 12-06-2021
# Invalid date format: 12-03-2021
# Invalid date format: 12-02-2021
# Invalid date format: 12-01-2021
# Invalid date format: 11-12-2021
# Invalid date format: 11-11-2021
# Invalid date format: 11-10-2021
# Invalid date format: 11-09-2021
# Invalid date format: 11-08-2021
# Invalid date format: 11-05-2021
# Invalid date format: 11-04-2021
# Invalid date format: 11-03-2021
# Invalid date format: 11-02-2021
# Invalid date format: 11-01-2021
# Invalid date format: 10-12-2021
# Invalid date format: 10-11-2021
# Invalid date format: 10-08-2021
# Invalid date format: 10-07-2021
# Invalid date format: 10-06-2021
# Invalid date format: 10-05-2021
# Invalid date format: 10-04-2021
# Invalid date format: 10-01-2021
# Invalid date format: 09-10-2021
# Invalid date format: 09-09-2021
# Invalid date format: 09-08-2021
# Invalid date format: 09-07-2021
# Invalid date format: 09-03-2021
# Invalid date format: 09-02-2021
# Invalid date format: 09-01-2021
# Invalid date format: 08-12-2021
# Invalid date format: 08-11-2021
# Invalid date format: 08-10-2021
# Invalid date format: 08-09-2021
# Invalid date format: 08-06-2021
# Invalid date format: 08-05-2021
# Invalid date format: 08-04-2021
# Invalid date format: 08-03-2021
# Invalid date format: 08-02-2021
# Invalid date format: 07-12-2021
# Invalid date format: 07-09-2021
# Invalid date format: 07-08-2021
# Invalid date format: 07-07-2021
# Invalid date format: 07-06-2021
# Invalid date format: 07-02-2021
# Invalid date format: 07-01-2021
# Invalid date format: 06-11-2021
# Invalid date format: 06-10-2021
# Invalid date format: 06-09-2021
# Invalid date format: 06-08-2021
# Invalid date format: 06-07-2021
# Invalid date format: 06-04-2021
# Invalid date format: 06-03-2021
# Invalid date format: 06-02-2021
# Invalid date format: 06-01-2021
# Invalid date format: 05-12-2021
# Invalid date format: 05-11-2021
# Invalid date format: 05-10-2021
# Invalid date format: 05-07-2021
# Invalid date format: 05-06-2021
# Invalid date format: 05-05-2021
# Invalid date format: 05-04-2021
# Invalid date format: 05-03-2021
# Invalid date format: 04-12-2021
# Invalid date format: 04-09-2021
# Invalid date format: 04-08-2021
# Invalid date format: 04-07-2021
# Invalid date format: 04-06-2021
# Invalid date format: 04-05-2021
# Invalid date format: 04-01-2021
# Invalid date format: 03-12-2021
# Invalid date format: 03-11-2021
# Invalid date format: 03-10-2021
# Invalid date format: 03-09-2021
# Invalid date format: 03-08-2021
# Invalid date format: 03-05-2021
# Invalid date format: 03-04-2021
# Invalid date format: 03-03-2021
# Invalid date format: 03-02-2021
# Invalid date format: 03-01-2021
# Invalid date format: 02-12-2021
# Invalid date format: 02-11-2021
# Invalid date format: 02-10-2021
# Invalid date format: 02-09-2021
# Invalid date format: 02-08-2021
# Invalid date format: 02-05-2021
# Invalid date format: 02-04-2021
# Invalid date format: 02-03-2021
# Invalid date format: 02-02-2021
# Invalid date format: 02-01-2021
# Invalid date format: 01-12-2021
# Invalid date format: 01-11-2021
# Invalid date format: 01-08-2021
# Invalid date format: 01-07-2021
# Invalid date format: 01-06-2021
# Invalid date format: 01-05-2021
# Invalid date format: 01-04-2021
# Invalid date format: 12-11-2020
# Invalid date format: 12-10-2020
# Invalid date format: 12-09-2020
# Invalid date format: 12-08-2020
# Invalid date format: 12-07-2020
# Invalid date format: 12-04-2020
# Invalid date format: 12-03-2020
# Invalid date format: 12-02-2020
# Invalid date format: 12-01-2020
# Invalid date format: 11-12-2020
# Invalid date format: 11-11-2020
# Invalid date format: 11-10-2020
# Invalid date format: 11-09-2020
# Invalid date format: 11-06-2020
# Invalid date format: 11-05-2020
# Invalid date format: 11-04-2020
# Invalid date format: 11-03-2020
# Invalid date format: 11-02-2020
# Invalid date format: 10-12-2020
# Invalid date format: 10-09-2020
# Invalid date format: 10-08-2020
# Invalid date format: 10-07-2020
# Invalid date format: 10-06-2020
# Invalid date format: 10-05-2020
# Invalid date format: 10-02-2020
# Invalid date format: 10-01-2020
# Invalid date format: 09-11-2020
# Invalid date format: 09-10-2020
# Invalid date format: 09-09-2020
# Invalid date format: 09-08-2020
# Invalid date format: 09-04-2020
# Invalid date format: 09-03-2020
# Invalid date format: 09-02-2020
# Invalid date format: 09-01-2020
# Invalid date format: 08-12-2020
# Invalid date format: 08-11-2020
# Invalid date format: 08-10-2020
# Invalid date format: 08-07-2020
# Invalid date format: 08-06-2020
# Invalid date format: 08-05-2020
# Invalid date format: 08-04-2020
# Invalid date format: 08-03-2020
# Invalid date format: 07-10-2020
# Invalid date format: 07-09-2020
# Invalid date format: 07-08-2020
# Invalid date format: 07-07-2020
# Invalid date format: 07-06-2020
# Invalid date format: 07-02-2020
# Invalid date format: 07-01-2020
# Invalid date format: 06-12-2020
# Invalid date format: 06-11-2020
# Invalid date format: 06-10-2020
# Invalid date format: 06-09-2020
# Invalid date format: 06-08-2020
# Invalid date format: 06-05-2020
# Invalid date format: 06-04-2020
# Invalid date format: 06-03-2020
# Invalid date format: 06-02-2020
# Invalid date format: 06-01-2020
# Invalid date format: 05-12-2020
# Invalid date format: 05-11-2020
# Invalid date format: 05-08-2020
# Invalid date format: 05-07-2020
# Invalid date format: 05-06-2020
# Invalid date format: 05-05-2020
# Invalid date format: 05-04-2020
# Invalid date format: 05-01-2020
# Invalid date format: 04-09-2020
# Invalid date format: 04-08-2020
# Invalid date format: 04-07-2020
# Invalid date format: 04-06-2020
# Invalid date format: 04-03-2020
# Invalid date format: 04-02-2020
# Invalid date format: 04-01-2020
# Invalid date format: 03-12-2020
# Invalid date format: 03-11-2020
# Invalid date format: 03-10-2020
# Invalid date format: 03-09-2020
# Invalid date format: 03-06-2020
# Invalid date format: 03-05-2020
# Invalid date format: 03-04-2020
# Invalid date format: 03-03-2020
# Invalid date format: 03-02-2020
# Invalid date format: 02-12-2020
# Invalid date format: 02-11-2020
# Invalid date format: 02-10-2020
# Invalid date format: 02-07-2020
# Invalid date format: 02-06-2020
# Invalid date format: 02-05-2020
# Invalid date format: 02-04-2020
# Invalid date format: 02-03-2020
# Invalid date format: 01-10-2020
# Invalid date format: 01-09-2020
# Invalid date format: 01-08-2020
# Invalid date format: 01-07-2020
# Invalid date format: 01-06-2020
# Invalid date format: 01-03-2020
# Invalid date format: 01-02-2020
# Invalid date format: 12-12-2019
# Invalid date format: 12-11-2019
# Invalid date format: 12-10-2019
# Invalid date format: 12-09-2019
# Invalid date format: 12-06-2019
# Invalid date format: 12-05-2019
# Invalid date format: 12-04-2019
# Invalid date format: 12-03-2019
# Invalid date format: 12-02-2019
# Invalid date format: 11-12-2019
# Invalid date format: 11-11-2019
# Invalid date format: 11-08-2019
# Invalid date format: 11-07-2019
# Invalid date format: 11-06-2019
# Invalid date format: 11-05-2019
# Invalid date format: 11-04-2019
# Invalid date format: 11-01-2019
# Invalid date format: 10-11-2019
# Invalid date format: 10-10-2019
# Invalid date format: 10-09-2019
# Invalid date format: 10-08-2019
# Invalid date format: 10-07-2019
# Invalid date format: 10-04-2019
# Invalid date format: 10-03-2019
# Invalid date format: 10-02-2019
# Invalid date format: 10-01-2019
# Invalid date format: 09-12-2019
# Invalid date format: 09-11-2019
# Invalid date format: 09-10-2019
# Invalid date format: 09-09-2019
# Invalid date format: 09-06-2019
# Invalid date format: 09-05-2019
# Invalid date format: 09-04-2019
# Invalid date format: 09-03-2019
# Invalid date format: 08-12-2019
# Invalid date format: 08-09-2019
# Invalid date format: 08-08-2019
# Invalid date format: 08-07-2019
# Invalid date format: 08-06-2019
# Invalid date format: 08-05-2019
# Invalid date format: 08-02-2019
# Invalid date format: 08-01-2019
# Invalid date format: 07-12-2019
# Invalid date format: 07-11-2019
# Invalid date format: 07-10-2019
# Invalid date format: 07-09-2019
# Invalid date format: 07-08-2019
# Invalid date format: 07-05-2019
# Invalid date format: 07-03-2019
# Invalid date format: 07-02-2019
# Invalid date format: 07-01-2019
# Invalid date format: 06-12-2019
# Invalid date format: 06-11-2019
# Invalid date format: 06-10-2019
# Invalid date format: 06-07-2019
# Invalid date format: 06-06-2019
# Invalid date format: 06-05-2019
# Invalid date format: 06-04-2019
# Invalid date format: 06-03-2019
# Invalid date format: 05-10-2019
# Invalid date format: 05-09-2019
# Invalid date format: 05-08-2019
# Invalid date format: 05-07-2019
# Invalid date format: 05-06-2019
# Invalid date format: 05-03-2019
# Invalid date format: 05-02-2019
# Invalid date format: 05-01-2019
# Invalid date format: 04-12-2019
# Invalid date format: 04-11-2019
# Invalid date format: 04-10-2019
# Invalid date format: 04-09-2019
# Invalid date format: 04-08-2019
# Invalid date format: 04-05-2019
# Invalid date format: 04-04-2019
# Invalid date format: 04-03-2019
# Invalid date format: 04-02-2019
# Invalid date format: 04-01-2019
# Invalid date format: 03-12-2019
# Invalid date format: 03-11-2019
# Invalid date format: 03-08-2019
# Invalid date format: 03-07-2019
# Invalid date format: 03-06-2019
# Invalid date format: 03-05-2019
# Invalid date format: 03-04-2019
# Invalid date format: 03-01-2019
# Invalid date format: 02-12-2019
# Invalid date format: 02-11-2019
# Invalid date format: 02-08-2019
# Invalid date format: 02-07-2019
# Invalid date format: 02-06-2019
# Invalid date format: 02-05-2019
# Invalid date format: 02-04-2019
# Invalid date format: 02-01-2019
# Invalid date format: 01-11-2019
# Invalid date format: 01-10-2019
# Invalid date format: 01-09-2019
# Invalid date format: 01-08-2019
# Invalid date format: 01-07-2019
# Invalid date format: 01-04-2019
# Invalid date format: 01-03-2019
# Invalid date format: 01-02-2019
# Invalid date format: 12-12-2018
# Invalid date format: 12-11-2018
# Invalid date format: 12-10-2018
# Invalid date format: 12-07-2018
# Invalid date format: 12-06-2018
# Invalid date format: 12-04-2018
# Invalid date format: 12-03-2018
# Invalid date format: 11-12-2018
# Invalid date format: 11-09-2018
# Invalid date format: 11-08-2018
# Invalid date format: 11-07-2018
# Invalid date format: 11-06-2018
# Invalid date format: 11-05-2018
# Invalid date format: 11-02-2018
# Invalid date format: 11-01-2018
# Invalid date format: 10-12-2018
# Invalid date format: 10-11-2018
# Invalid date format: 10-10-2018
# Invalid date format: 10-09-2018
# Invalid date format: 10-08-2018
# Invalid date format: 10-05-2018
# Invalid date format: 10-04-2018
# Invalid date format: 10-03-2018
# Invalid date format: 10-02-2018
# Invalid date format: 10-01-2018
# Invalid date format: 09-12-2018
# Invalid date format: 09-11-2018
# Invalid date format: 09-10-2018
# Invalid date format: 09-07-2018
# Invalid date format: 09-06-2018
# Invalid date format: 09-05-2018
# Invalid date format: 09-04-2018
# Invalid date format: 08-10-2018
# Invalid date format: 08-09-2018
# Invalid date format: 08-08-2018
# Invalid date format: 08-07-2018
# Invalid date format: 08-06-2018
# Invalid date format: 08-03-2018
# Invalid date format: 08-02-2018
# Invalid date format: 08-01-2018
# Invalid date format: 07-12-2018
# Invalid date format: 07-11-2018
# Invalid date format: 07-10-2018
# Invalid date format: 07-09-2018
# Invalid date format: 07-06-2018
# Invalid date format: 07-05-2018
# Invalid date format: 07-03-2018
# Invalid date format: 07-02-2018
# Invalid date format: 06-12-2018
# Invalid date format: 06-11-2018
# Invalid date format: 06-08-2018
# Invalid date format: 06-07-2018
# Invalid date format: 06-06-2018
# Invalid date format: 06-05-2018
# Invalid date format: 06-04-2018
# Invalid date format: 06-01-2018
# Invalid date format: 05-11-2018
# Invalid date format: 05-10-2018
# Invalid date format: 05-09-2018
# Invalid date format: 05-08-2018
# Invalid date format: 05-07-2018
# Invalid date format: 05-04-2018
# Invalid date format: 05-03-2018
# Invalid date format: 05-02-2018
# Invalid date format: 05-01-2018
# Invalid date format: 04-12-2018
# Invalid date format: 04-11-2018
# Invalid date format: 04-10-2018
# Invalid date format: 04-09-2018
# Invalid date format: 04-06-2018
# Invalid date format: 04-05-2018
# Invalid date format: 04-04-2018
# Invalid date format: 04-03-2018
# Invalid date format: 04-02-2018
# Invalid date format: 03-12-2018
# Invalid date format: 03-09-2018
# Invalid date format: 03-08-2018
# Invalid date format: 03-07-2018
# Invalid date format: 03-06-2018
# Invalid date format: 03-05-2018
# Invalid date format: 03-02-2018
# Invalid date format: 03-01-2018
# Invalid date format: 02-12-2018
# Invalid date format: 02-09-2018
# Invalid date format: 02-08-2018
# Invalid date format: 02-07-2018
# Invalid date format: 02-06-2018
# Invalid date format: 02-05-2018
# Invalid date format: 02-02-2018
# Invalid date format: 02-01-2018
# Invalid date format: 01-12-2018
# Invalid date format: 01-11-2018
# Invalid date format: 01-10-2018
# Invalid date format: 01-09-2018
# Invalid date format: 01-08-2018
# Invalid date format: 01-05-2018
# Invalid date format: 01-04-2018
# Invalid date format: 01-03-2018
# Invalid date format: 01-02-2018
# Invalid date format: 12-12-2017
# Invalid date format: 12-11-2017
# Invalid date format: 12-08-2017
# Invalid date format: 12-07-2017
# Invalid date format: 12-06-2017
# Invalid date format: 12-05-2017
# Invalid date format: 12-04-2017
# Invalid date format: 12-01-2017
# Invalid date format: 11-10-2017
# Invalid date format: 11-09-2017
# Invalid date format: 11-08-2017
# Invalid date format: 11-07-2017
# Invalid date format: 11-06-2017
# Invalid date format: 11-03-2017
# Invalid date format: 11-02-2017
# Invalid date format: 11-01-2017
# Invalid date format: 10-12-2017
# Invalid date format: 10-11-2017
# Invalid date format: 10-10-2017
# Invalid date format: 10-09-2017
# Invalid date format: 10-06-2017
# Invalid date format: 10-05-2017
# Invalid date format: 10-04-2017
# Invalid date format: 10-03-2017
# Invalid date format: 10-02-2017
# Invalid date format: 09-12-2017
# Invalid date format: 09-11-2017
# Invalid date format: 09-08-2017
# Invalid date format: 09-07-2017
# Invalid date format: 09-06-2017
# Invalid date format: 09-05-2017
# Invalid date format: 09-01-2017
# Invalid date format: 08-11-2017
# Invalid date format: 08-10-2017
# Invalid date format: 08-09-2017
# Invalid date format: 08-08-2017
# Invalid date format: 08-07-2017
# Invalid date format: 08-04-2017
# Invalid date format: 08-03-2017
# Invalid date format: 08-02-2017
# Invalid date format: 08-01-2017
# Invalid date format: 07-12-2017
# Invalid date format: 07-11-2017
# Invalid date format: 07-10-2017
# Invalid date format: 07-07-2017
# Invalid date format: 07-06-2017
# Invalid date format: 07-05-2017
# Invalid date format: 07-03-2017
# Invalid date format: 06-12-2017
# Invalid date format: 06-09-2017
# Invalid date format: 06-08-2017
# Invalid date format: 06-07-2017
# Invalid date format: 06-06-2017
# Invalid date format: 06-05-2017
# Invalid date format: 06-02-2017
# Invalid date format: 06-01-2017
# Invalid date format: 05-12-2017
# Invalid date format: 05-11-2017
# Invalid date format: 05-10-2017
# Invalid date format: 05-09-2017
# Invalid date format: 05-08-2017
# Invalid date format: 05-05-2017
# Invalid date format: 05-04-2017
# Invalid date format: 05-03-2017
# Invalid date format: 05-02-2017
# Invalid date format: 05-01-2017
# Invalid date format: 04-12-2017
# Invalid date format: 04-11-2017
# Invalid date format: 04-10-2017
# Invalid date format: 04-07-2017
# Invalid date format: 04-06-2017
# Invalid date format: 04-05-2017
# Invalid date format: 04-04-2017
# Invalid date format: 04-03-2017
# Invalid date format: 03-10-2017
# Invalid date format: 03-09-2017
# Invalid date format: 03-08-2017
# Invalid date format: 03-07-2017
# Invalid date format: 03-06-2017
# Invalid date format: 03-03-2017
# Invalid date format: 03-02-2017
# Invalid date format: 03-01-2017
# Invalid date format: 02-10-2017
# Invalid date format: 02-09-2017
# Invalid date format: 02-08-2017
# Invalid date format: 02-07-2017
# Invalid date format: 02-06-2017
# Invalid date format: 02-03-2017
# Invalid date format: 02-02-2017
# Invalid date format: 02-01-2017
# Invalid date format: 01-12-2017
# Invalid date format: 01-11-2017
# Invalid date format: 01-10-2017
# Invalid date format: 01-09-2017
# Invalid date format: 01-06-2017
# Invalid date format: 01-05-2017
# Invalid date format: 01-04-2017
# Invalid date format: 01-03-2017
# Invalid date format: 12-12-2016
# Invalid date format: 12-09-2016
# Invalid date format: 12-08-2016
# Invalid date format: 12-07-2016
# Invalid date format: 12-06-2016
# Invalid date format: 12-05-2016
# Invalid date format: 12-02-2016
# Invalid date format: 12-01-2016
# Invalid date format: 11-11-2016
# Invalid date format: 11-10-2016
# Invalid date format: 11-09-2016
# Invalid date format: 11-08-2016
# Invalid date format: 11-07-2016
# Invalid date format: 11-04-2016
# Invalid date format: 11-03-2016
# Invalid date format: 11-02-2016
# Invalid date format: 11-01-2016
# Invalid date format: 10-12-2016
# Invalid date format: 10-11-2016
# Invalid date format: 10-10-2016
# Invalid date format: 10-07-2016
# Invalid date format: 10-06-2016
# Invalid date format: 10-05-2016
# Invalid date format: 10-04-2016
# Invalid date format: 10-03-2016
# Invalid date format: 09-12-2016
# Invalid date format: 09-09-2016
# Invalid date format: 09-08-2016
# Invalid date format: 09-07-2016
# Invalid date format: 09-06-2016
# Invalid date format: 09-02-2016
# Invalid date format: 09-01-2016
# Invalid date format: 08-12-2016
# Invalid date format: 08-11-2016
# Invalid date format: 08-10-2016
# Invalid date format: 08-09-2016
# Invalid date format: 08-08-2016
# Invalid date format: 08-05-2016
# Invalid date format: 08-04-2016
# Invalid date format: 08-03-2016
# Invalid date format: 08-02-2016
# Invalid date format: 08-01-2016
# Invalid date format: 07-12-2016
# Invalid date format: 07-11-2016
# Invalid date format: 07-08-2016
# Invalid date format: 07-07-2016
# Invalid date format: 07-06-2016
# Invalid date format: 07-05-2016
# Invalid date format: 07-01-2016
# Invalid date format: 06-10-2016
# Invalid date format: 06-09-2016
# Invalid date format: 06-08-2016
# Invalid date format: 06-07-2016
# Invalid date format: 06-06-2016
# Invalid date format: 06-03-2016
# Invalid date format: 06-02-2016
# Invalid date format: 06-01-2016
# Invalid date format: 05-12-2016
# Invalid date format: 05-11-2016
# Invalid date format: 05-10-2016
# Invalid date format: 05-09-2016
# Invalid date format: 05-06-2016
# Invalid date format: 05-05-2016
# Invalid date format: 05-04-2016
# Invalid date format: 05-03-2016
# Invalid date format: 05-02-2016
# Invalid date format: 04-12-2016
# Invalid date format: 04-11-2016
# Invalid date format: 04-08-2016
# Invalid date format: 04-07-2016
# Invalid date format: 04-06-2016
# Invalid date format: 04-05-2016
# Invalid date format: 04-04-2016
# Invalid date format: 04-01-2016
# Invalid date format: 03-11-2016
# Invalid date format: 03-10-2016
# Invalid date format: 03-09-2016
# Invalid date format: 03-08-2016
# Invalid date format: 03-07-2016
# Invalid date format: 03-04-2016
# Invalid date format: 03-03-2016
# Invalid date format: 03-02-2016
# Invalid date format: 03-01-2016
# Invalid date format: 02-12-2016
# Invalid date format: 02-11-2016
# Invalid date format: 02-10-2016
# Invalid date format: 02-09-2016
# Invalid date format: 02-08-2016
# Invalid date format: 02-05-2016
# Invalid date format: 02-04-2016
# Invalid date format: 02-03-2016
# Invalid date format: 02-02-2016
# Invalid date format: 02-01-2016
# Invalid date format: 01-12-2016
# Invalid date format: 01-11-2016
# Invalid date format: 01-08-2016
# Invalid date format: 01-07-2016
# Invalid date format: 01-06-2016
# Invalid date format: 01-05-2016
# Invalid date format: 01-04-2016
# Invalid date format: 12-11-2015
# Invalid date format: 12-10-2015
# Invalid date format: 12-09-2015
# Invalid date format: 12-08-2015
# Invalid date format: 12-07-2015
# Invalid date format: 12-04-2015
# Invalid date format: 12-03-2015
# Invalid date format: 12-02-2015
# Invalid date format: 12-01-2015
# Invalid date format: 11-12-2015
# Invalid date format: 11-11-2015
# Invalid date format: 11-10-2015
# Invalid date format: 11-09-2015
# Invalid date format: 11-06-2015
# Invalid date format: 11-05-2015
# Invalid date format: 11-04-2015
# Invalid date format: 11-03-2015
# Invalid date format: 11-02-2015
# Invalid date format: 10-12-2015
# Invalid date format: 10-09-2015
# Invalid date format: 10-08-2015
# Invalid date format: 10-07-2015
# Invalid date format: 10-06-2015
# Invalid date format: 10-05-2015
# Invalid date format: 10-02-2015
# Invalid date format: 10-01-2015
# Invalid date format: 09-11-2015
# Invalid date format: 09-10-2015
# Invalid date format: 09-09-2015
# Invalid date format: 09-08-2015
# Invalid date format: 09-04-2015
# Invalid date format: 09-03-2015
# Invalid date format: 09-02-2015
# Invalid date format: 09-01-2015
# Invalid date format: 08-12-2015
# Invalid date format: 08-11-2015
# Invalid date format: 08-10-2015
# Invalid date format: 08-07-2015
# Invalid date format: 08-06-2015
# Invalid date format: 08-05-2015
# Invalid date format: 08-04-2015
# Invalid date format: 08-03-2015
# Invalid date format: 07-10-2015
# Invalid date format: 07-09-2015
# Invalid date format: 07-08-2015
# Invalid date format: 07-07-2015
# Invalid date format: 07-06-2015
# Invalid date format: 07-02-2015
# Invalid date format: 07-01-2015
# Invalid date format: 06-12-2015
# Invalid date format: 06-11-2015
# Invalid date format: 06-10-2015
# Invalid date format: 06-09-2015
# Invalid date format: 06-08-2015
# Invalid date format: 06-05-2015
# Invalid date format: 06-04-2015
# Invalid date format: 06-03-2015
# Invalid date format: 06-02-2015
# Invalid date format: 06-01-2015
# Invalid date format: 05-12-2015
# Invalid date format: 05-11-2015
# Invalid date format: 05-08-2015
# Invalid date format: 05-07-2015
# Invalid date format: 05-06-2015
# Invalid date format: 05-05-2015
# Invalid date format: 05-04-2015
# Invalid date format: 05-01-2015
# Invalid date format: 04-10-2015
# Invalid date format: 04-09-2015
# Invalid date format: 04-08-2015
# Invalid date format: 04-07-2015
# Invalid date format: 04-06-2015
# Invalid date format: 04-02-2015
# Invalid date format: 04-01-2015
# Invalid date format: 03-12-2015
# Invalid date format: 03-11-2015
# Invalid date format: 03-10-2015
# Invalid date format: 03-09-2015
# Invalid date format: 03-06-2015
# Invalid date format: 03-05-2015
# Invalid date format: 03-04-2015
# Invalid date format: 03-03-2015
# Invalid date format: 03-02-2015
# Invalid date format: 02-12-2015
# Invalid date format: 02-11-2015
# Invalid date format: 02-10-2015
# Invalid date format: 02-09-2015
# Invalid date format: 02-06-2015
# Invalid date format: 02-05-2015
# Invalid date format: 02-04-2015
# Invalid date format: 02-03-2015
# Invalid date format: 02-02-2015
# Invalid date format: 01-12-2015
# Invalid date format: 01-09-2015
# Invalid date format: 01-08-2015
# Invalid date format: 01-07-2015
# Invalid date format: 01-06-2015
# Invalid date format: 01-05-2015
# Invalid date format: 01-02-2015
# Invalid date format: 12-12-2014
# Invalid date format: 12-11-2014
# Invalid date format: 12-10-2014
# Invalid date format: 12-09-2014
# Invalid date format: 12-08-2014
# Invalid date format: 12-05-2014
# Invalid date format: 12-04-2014
# Invalid date format: 12-03-2014
# Invalid date format: 12-02-2014
# Invalid date format: 12-01-2014
# Invalid date format: 11-12-2014
# Invalid date format: 11-11-2014
# Invalid date format: 11-10-2014
# Invalid date format: 11-07-2014
# Invalid date format: 11-06-2014
# Invalid date format: 11-05-2014
# Invalid date format: 11-04-2014
# Invalid date format: 11-03-2014
# Conversion complete. Output saved to 'NVDA_output.csv'.

# %%
import csv
import os
from datetime import datetime

def convert_all_csv_files(output_suffix='_output.csv'):
    """
    Converts all CSV files in the current directory to the desired format.
    Each output file is named by appending '_output.csv' to the original filename (e.g., 'NVDA.csv' -> 'NVDA_output.csv').

    The output CSV files do not contain a header row.
    """
    # Get the directory where the script is located
    script_dir = os.path.dirname(os.path.abspath(__file__))

    # List all files in the directory
    for filename in os.listdir(script_dir):
        # Process only .csv files and exclude output files to prevent re-processing
        if filename.lower().endswith('.csv') and not filename.endswith(output_suffix):
            input_file = os.path.join(script_dir, filename)
            symbol = os.path.splitext(filename)[0]
            output_filename = f"{symbol}{output_suffix}"
            output_file = os.path.join(script_dir, output_filename)

            print(f"Processing '{filename}' -> '{output_filename}'")

            with open(input_file, 'r', newline='', encoding='utf-8') as infile, \
                 open(output_file, 'w', newline='', encoding='utf-8') as outfile:

                reader = csv.reader(infile)
                writer = csv.writer(outfile)

                # Skip the header row in the input CSV
                header = next(reader, None)
                if header is None:
                    print(f"Warning: '{filename}' is empty. Skipping.")
                    continue

                for row_number, row in enumerate(reader, start=2):  # Start at 2 to account for header
                    if not row:
                        print(f"Skipping empty row {row_number} in '{filename}'.")
                        continue  # Skip empty rows

                    try:
                        # Unpack the input row
                        date_str, close_last, volume, open_price, high, low = row

                        # Convert date from mm/dd/yyyy to yyyymmdd
                        date_obj = datetime.strptime(date_str.strip(), '%m/%d/%Y')
                        formatted_date = date_obj.strftime('%Y%m%d')

                        # Remove '$' and ',' from numeric fields
                        close_last = close_last.replace('$', '').replace(',', '').strip()
                        open_price = open_price.replace('$', '').replace(',', '').strip()
                        high = high.replace('$', '').replace(',', '').strip()
                        low = low.replace('$', '').replace(',', '').strip()
                        volume = volume.replace('$', '').replace(',', '').strip()

                        # Create the output row in the required order
                        output_row = [
                            symbol,
                            formatted_date,
                            open_price,
                            high,
                            low,
                            close_last,
                            volume
                        ]

                        writer.writerow(output_row)

                    except ValueError as ve:
                        print(f"Error processing row {row_number} in '{filename}': {ve}. Skipping row.")
                    except IndexError:
                        print(f"Error: Row {row_number} in '{filename}' does not have enough columns. Skipping row.")

            print(f"Finished processing '{filename}'. Output saved to '{output_filename}'.\n")

    print("All CSV files have been processed.")

# Example usage
if __name__ == "__main__":
    convert_all_csv_files()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 82
#      80 # Example usage
#      81 if __name__ == "__main__":
# ---> 82     convert_all_csv_files()
#
# Cell In[3], line 13, in convert_all_csv_files(output_suffix)
#       6 """
#       7 Converts all CSV files in the current directory to the desired format.
#       8 Each output file is named by appending '_output.csv' to the original filename (e.g., 'NVDA.csv' -> 'NVDA_output.csv').
#       9
#      10 The output CSV files do not contain a header row.
#      11 """
#      12 # Get the directory where the script is located
# ---> 13 script_dir = os.path.dirname(os.path.abspath(__file__))
#      15 # List all files in the directory
#      16 for filename in os.listdir(script_dir):
#      17     # Process only .csv files and exclude output files to prevent re-processing
#
# NameError: name '__file__' is not defined
